# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("exams.csv")

# %%
df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group C                 high school      standard
# 1   female        group C                 high school      standard
# 2     male        group D                 high school      standard
# 3     male        group E                 high school  free/reduced
# 4   female        group D                some college  free/reduced
# ..     ...            ...                         ...           ...
# 95  female        group C          associate's degree  free/reduced
# 96  female        group D                 high school      standard
# 97  female        group E                 high school      standard
# 98    male        group C          associate's degree      standard
# 99    male        group C                some college      standard
#
#    test preparation course  math score  reading score  writing score
# 0                     none          45             46             46
# 1                     none          78             88             90
# 2                     none          76             65             72
# 3                     none          71             60             56
# 4                     none          57             81             75
# ..                     ...         ...            ...            ...
# 95                    none          49             61             61
# 96               completed          68             83             87
# 97                    none          60             64             66
# 98               completed          48             40             48
# 99                    none          71             69             66
#
# [100 rows x 8 columns]

# %%
attribute_cols = df.select_dtypes(include='object').columns

# %%
attribute_cols
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course'],
#       dtype='object')

# %%
for i in attribute_cols:
    print(df[i].unique())
# Out:
# ['female' 'male']
# ['group C' 'group D' 'group E' 'group B' 'group A']
# ['high school' 'some college' "bachelor's degree" "master's degree"
#  'some high school' "associate's degree"]
# ['standard' 'free/reduced']
# ['none' 'completed']

# %%
df.isnull().sum()              #checking for null values
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
sns.countplot(df['gender'])
# Out:
# C:\Users\kishore\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
#students take preparatory classes
count_test = df['test preparation course'].value_counts()
labels = df['test preparation course'].value_counts().index
plt.figure(figsize= (6,6))
plt.pie(count_test,labels=labels,autopct='%1.1f%%')
plt.legend(labels)
plt.show()

# %%
df['average_score']=(df['math score']+df['reading score']+df['writing score'])/3
df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group C                 high school      standard
# 1   female        group C                 high school      standard
# 2     male        group D                 high school      standard
# 3     male        group E                 high school  free/reduced
# 4   female        group D                some college  free/reduced
# ..     ...            ...                         ...           ...
# 95  female        group C          associate's degree  free/reduced
# 96  female        group D                 high school      standard
# 97  female        group E                 high school      standard
# 98    male        group C          associate's degree      standard
# 99    male        group C                some college      standard
#
#    test preparation course  math score  reading score  writing score  \
# 0                     none          45             46             46
# 1                     none          78             88             90
# 2                     none          76             65             72
# 3                     none          71             60             56
# 4                     none          57             81             75
# ..                     ...         ...            ...            ...
# 95                    none          49             61             61
# 96               completed          68             83             87
# 97                    none          60             64             66
# 98               completed          48             40             48
# 99                    none          71             69             66
#
#     average_score
# 0       45.666667
# 1       85.333333
# 2       71.000000
# 3       62.333333
# 4       71.000000
# ..            ...
# 95      57.000000
# 96      79.333333
# 97      63.333333
# 98      45.333333
# 99      68.666667
#
# [100 rows x 9 columns]

# %% [markdown]
# ***Students performance on math based on gender***

# %%
sns.scatterplot(x=df['average_score'],y=df['math score'],hue=df['gender'])
# Out:
# <AxesSubplot:xlabel='average_score', ylabel='math score'>

# %% [markdown]
# ***Students performance on reading based on gender***

# %%
sns.scatterplot(x=df['average_score'],y=df['reading score'],hue=df['gender'])
# Out:
# <AxesSubplot:xlabel='average_score', ylabel='reading score'>

# %% [markdown]
# ***Students performance on writing based on gender***

# %%
sns.scatterplot(x=df['average_score'],y=df['writing score'],hue=df['gender'])
# Out:
# <AxesSubplot:xlabel='average_score', ylabel='writing score'>

# %%
df
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group C                 high school      standard
# 1   female        group C                 high school      standard
# 2     male        group D                 high school      standard
# 3     male        group E                 high school  free/reduced
# 4   female        group D                some college  free/reduced
# ..     ...            ...                         ...           ...
# 95  female        group C          associate's degree  free/reduced
# 96  female        group D                 high school      standard
# 97  female        group E                 high school      standard
# 98    male        group C          associate's degree      standard
# 99    male        group C                some college      standard
#
#    test preparation course  math score  reading score  writing score  \
# 0                     none          45             46             46
# 1                     none          78             88             90
# 2                     none          76             65             72
# 3                     none          71             60             56
# 4                     none          57             81             75
# ..                     ...         ...            ...            ...
# 95                    none          49             61             61
# 96               completed          68             83             87
# 97                    none          60             64             66
# 98               completed          48             40             48
# 99                    none          71             69             66
#
#     average_score
# 0       45.666667
# 1       85.333333
# 2       71.000000
# 3       62.333333
# 4       71.000000
# ..            ...
# 95      57.000000
# 96      79.333333
# 97      63.333333
# 98      45.333333
# 99      68.666667
#
# [100 rows x 9 columns]

# %%
gender = {
    'male':1,
    'female':0
}

# %%
race = {
    'group A':0,
    'group B':1,
    'group C':2,
    'group D':3,
    'group E':4
}

# %%
df['gender']=df['gender'].map(gender)
df['race/ethnicity']=df['race/ethnicity'].map(race)

# %%
df
# Out:
#     gender  race/ethnicity parental level of education         lunch  \
# 0        0               2                 high school      standard
# 1        0               2                 high school      standard
# 2        1               3                 high school      standard
# 3        1               4                 high school  free/reduced
# 4        0               3                some college  free/reduced
# ..     ...             ...                         ...           ...
# 95       0               2          associate's degree  free/reduced
# 96       0               3                 high school      standard
# 97       0               4                 high school      standard
# 98       1               2          associate's degree      standard
# 99       1               2                some college      standard
#
#    test preparation course  math score  reading score  writing score  \
# 0                     none          45             46             46
# 1                     none          78             88             90
# 2                     none          76             65             72
# 3                     none          71             60             56
# 4                     none          57             81             75
# ..                     ...         ...            ...            ...
# 95                    none          49             61             61
# 96               completed          68             83             87
# 97                    none          60             64             66
# 98               completed          48             40             48
# 99                    none          71             69             66
#
#     average_score
# 0       45.666667
# 1       85.333333
# 2       71.000000
# 3       62.333333
# 4       71.000000
# ..            ...
# 95      57.000000
# 96      79.333333
# 97      63.333333
# 98      45.333333
# 99      68.666667
#
# [100 rows x 9 columns]

# %%
level = {
    "bachelor's degree":0,
    'some college':1,
    "master's degree":2,
    "associate's degree":3,
    "high school":4,
    "some high school":5
}

# %%
df['parental level of education']=df['parental level of education'].map(level)

# %%
df
# Out:
#     gender  race/ethnicity  parental level of education         lunch  \
# 0        0               2                            4      standard
# 1        0               2                            4      standard
# 2        1               3                            4      standard
# 3        1               4                            4  free/reduced
# 4        0               3                            1  free/reduced
# ..     ...             ...                          ...           ...
# 95       0               2                            3  free/reduced
# 96       0               3                            4      standard
# 97       0               4                            4      standard
# 98       1               2                            3      standard
# 99       1               2                            1      standard
#
#    test preparation course  math score  reading score  writing score  \
# 0                     none          45             46             46
# 1                     none          78             88             90
# 2                     none          76             65             72
# 3                     none          71             60             56
# 4                     none          57             81             75
# ..                     ...         ...            ...            ...
# 95                    none          49             61             61
# 96               completed          68             83             87
# 97                    none          60             64             66
# 98               completed          48             40             48
# 99                    none          71             69             66
#
#     average_score
# 0       45.666667
# 1       85.333333
# 2       71.000000
# 3       62.333333
# 4       71.000000
# ..            ...
# 95      57.000000
# 96      79.333333
# 97      63.333333
# 98      45.333333
# 99      68.666667
#
# [100 rows x 9 columns]

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#     gender  race/ethnicity  parental level of education  math score  \
# 0        0               2                            4          45
# 1        0               2                            4          78
# 2        1               3                            4          76
# 3        1               4                            4          71
# 4        0               3                            1          57
# ..     ...             ...                          ...         ...
# 95       0               2                            3          49
# 96       0               3                            4          68
# 97       0               4                            4          60
# 98       1               2                            3          48
# 99       1               2                            1          71
#
#     reading score  writing score  average_score  lunch_standard  \
# 0              46             46      45.666667               1
# 1              88             90      85.333333               1
# 2              65             72      71.000000               1
# 3              60             56      62.333333               0
# 4              81             75      71.000000               0
# ..            ...            ...            ...             ...
# 95             61             61      57.000000               0
# 96             83             87      79.333333               1
# 97             64             66      63.333333               1
# 98             40             48      45.333333               1
# 99             69             66      68.666667               1
#
#     test preparation course_none
# 0                              1
# 1                              1
# 2                              1
# 3                              1
# 4                              1
# ..                           ...
# 95                             1
# 96                             0
# 97                             1
# 98                             0
# 99                             1
#
# [100 rows x 9 columns]

# %%
x = df.drop(columns='average_score').values

# %%
x
# Out:
# array([[  0,   2,   4,  45,  46,  46,   1,   1],
#        [  0,   2,   4,  78,  88,  90,   1,   1],
#        [  1,   3,   4,  76,  65,  72,   1,   1],
#        [  1,   4,   4,  71,  60,  56,   0,   1],
#        [  0,   3,   1,  57,  81,  75,   0,   1],
#        [  0,   1,   0,  78,  84,  88,   1,   1],
#        [  0,   3,   4,  67,  82,  77,   1,   1],
#        [  1,   4,   2,  75,  66,  60,   0,   0],
#        [  1,   1,   1,  73,  62,  69,   1,   1],
#        [  0,   2,   2,  89,  96,  98,   1,   0],
#        [  0,   2,   0,  35,  45,  49,   0,   1],
#        [  0,   2,   4,  70,  71,  65,   1,   1],
#        [  0,   2,   4,  80,  91, 100,   1,   0],
#        [  1,   2,   4,  67,  72,  64,   0,   0],
#        [  1,   1,   5,  77,  83,  79,   1,   1],
#        [  0,   3,   4,  84,  82,  85,   1,   1],
#        [  0,   2,   4,  43,  51,  44,   1,   1],
#        [  0,   1,   1,  63,  72,  70,   1,   1],
#        [  1,   0,   0,  81,  66,  65,   1,   1],
#        [  1,   1,   3,  71,  75,  75,   0,   0],
#        [  0,   2,   5,  69,  77,  78,   1,   1],
#        [  0,   1,   4,  39,  48,  55,   0,   1],
#        [  1,   1,   3,  81,  77,  69,   1,   1],
#        [  1,   2,   3,  43,  51,  46,   1,   1],
#        [  1,   1,   4,  64,  48,  47,   1,   1],
#        [  0,   1,   4,  55,  73,  68,   1,   1],
#        [  0,   2,   3,  43,  53,  62,   1,   0],
#        [  0,   4,   4,  92,  96,  88,   1,   1],
#        [  1,   4,   2,  74,  71,  67,   1,   1],
#        [  1,   3,   0,  45,  44,  50,   0,   1],
#        [  0,   4,   2,  74,  89,  83,   0,   0],
#        [  1,   3,   3,  81,  80,  83,   1,   0],
#        [  0,   3,   3,  47,  68,  66,   1,   1],
#        [  1,   1,   3,  83,  86,  88,   0,   0],
#        [  1,   3,   3,  57,  47,  50,   0,   1],
#        [  1,   4,   5,  91,  86,  84,   1,   0],
#        [  1,   3,   4,  51,  53,  43,   0,   1],
#        [  1,   2,   3,  61,  60,  56,   0,   1],
#        [  0,   3,   3,  64,  65,  73,   1,   1],
#        [  1,   3,   1,  73,  71,  69,   1,   0],
#        [  1,   2,   1,  65,  69,  65,   0,   1],
#        [  1,   2,   2,  55,  64,  62,   0,   0],
#        [  1,   1,   3,  47,  45,  45,   1,   0],
#        [  0,   3,   5,  54,  68,  67,   1,   0],
#        [  1,   3,   5,  58,  60,  59,   1,   1],
#        [  1,   2,   4,  66,  60,  62,   0,   0],
#        [  0,   1,   1,  50,  64,  59,   0,   0],
#        [  1,   2,   0,  79,  69,  69,   1,   0],
#        [  1,   2,   5,  77,  74,  69,   1,   1],
#        [  1,   1,   2,  80,  80,  71,   1,   1],
#        [  1,   1,   3, 100,  84,  89,   1,   0],
#        [  1,   4,   1,  64,  72,  65,   0,   0],
#        [  1,   2,   1,  60,  63,  58,   0,   0],
#        [  1,   1,   5,  89,  88,  82,   1,   1],
#        [  0,   3,   0,  64,  72,  73,   1,   1],
#        [  0,   1,   4,  61,  59,  60,   1,   1],
#        [  0,   3,   4,  58,  65,  61,   0,   1],
#        [  1,   3,   1,  68,  72,  70,   1,   1],
#        [  0,   3,   1,  18,  31,  32,   0,   1],
#        [  1,   0,   5,  84,  89,  91,   1,   0],
#        [  1,   2,   4,  61,  56,  54,   1,   1],
#        [  1,   0,   3,  82,  73,  79,   1,   1],
#        [  0,   3,   4,  61,  68,  77,   1,   0],
#        [  1,   2,   3,  58,  64,  61,   0,   0],
#        [  1,   2,   3,  59,  53,  49,   1,   1],
#        [  0,   2,   4,  86,  90,  91,   1,   1],
#        [  1,   4,   4,  83,  72,  69,   1,   0],
#        [  1,   2,   5,  64,  73,  64,   0,   1],
#        [  0,   0,   1,  60,  77,  71,   1,   1],
#        [  1,   3,   3,  75,  72,  68,   1,   1],
#        [  0,   2,   4,  60,  71,  72,   0,   0],
#        [  1,   0,   2,  49,  50,  48,   0,   1],
#        [  0,   0,   4,  73,  81,  75,   1,   1],
#        [  0,   2,   4,  44,  53,  50,   0,   1],
#        [  0,   2,   5,  58,  71,  71,   1,   1],
#        [  0,   3,   1,  64,  77,  75,   1,   1],
#        [  0,   3,   4,  80,  86,  88,   1,   1],
#        [  1,   1,   2,  70,  73,  72,   0,   1],
#        [  0,   4,   0,  63,  74,  71,   0,   0],
#        [  1,   2,   4,  63,  57,  54,   1,   1],
#        [  1,   2,   0,  59,  42,  47,   1,   1],
#        [  1,   3,   3,  76,  81,  79,   1,   0],
#        [  0,   1,   1,  80,  90,  92,   1,   0],
#        [  0,   3,   5,  81,  84,  83,   1,   1],
#        [  0,   2,   1,  78,  84,  80,   0,   0],
#        [  0,   4,   4,  73,  80,  75,   1,   1],
#        [  0,   4,   4,  80,  95,  97,   0,   0],
#        [  1,   3,   2,  59,  66,  65,   0,   1],
#        [  1,   3,   1,  87,  70,  71,   1,   1],
#        [  0,   0,   2,  88,  95,  96,   1,   0],
#        [  0,   3,   4,  38,  32,  36,   0,   1],
#        [  1,   4,   0,  71,  67,  65,   1,   1],
#        [  1,   0,   3,  76,  78,  81,   1,   0],
#        [  0,   2,   5,  64,  74,  66,   1,   1],
#        [  0,   1,   4,  53,  57,  58,   1,   1],
#        [  0,   2,   3,  49,  61,  61,   0,   1],
#        [  0,   3,   4,  68,  83,  87,   1,   0],
#        [  0,   4,   4,  60,  64,  66,   1,   1],
#        [  1,   2,   3,  48,  40,  48,   1,   0],
#        [  1,   2,   1,  71,  69,  66,   1,   1]], dtype=int64)

# %%
x[0]
# Out:
# array([ 0,  2,  4, 45, 46, 46,  1,  1], dtype=int64)

# %%
y = df['average_score'].values

# %%
y
# Out:
# array([45.66666667, 85.33333333, 71.        , 62.33333333, 71.        ,
#        83.33333333, 75.33333333, 67.        , 68.        , 94.33333333,
#        43.        , 68.66666667, 90.33333333, 67.66666667, 79.66666667,
#        83.66666667, 46.        , 68.33333333, 70.66666667, 73.66666667,
#        74.66666667, 47.33333333, 75.66666667, 46.66666667, 53.        ,
#        65.33333333, 52.66666667, 92.        , 70.66666667, 46.33333333,
#        82.        , 81.33333333, 60.33333333, 85.66666667, 51.33333333,
#        87.        , 49.        , 59.        , 67.33333333, 71.        ,
#        66.33333333, 60.33333333, 45.66666667, 63.        , 59.        ,
#        62.66666667, 57.66666667, 72.33333333, 73.33333333, 77.        ,
#        91.        , 67.        , 60.33333333, 86.33333333, 69.66666667,
#        60.        , 61.33333333, 70.        , 27.        , 88.        ,
#        57.        , 78.        , 68.66666667, 61.        , 53.66666667,
#        89.        , 74.66666667, 67.        , 69.33333333, 71.66666667,
#        67.66666667, 49.        , 76.33333333, 49.        , 66.66666667,
#        72.        , 84.66666667, 71.66666667, 69.33333333, 58.        ,
#        49.33333333, 78.66666667, 87.33333333, 82.66666667, 80.66666667,
#        76.        , 90.66666667, 63.33333333, 76.        , 93.        ,
#        35.33333333, 67.66666667, 78.33333333, 68.        , 56.        ,
#        57.        , 79.33333333, 63.33333333, 45.33333333, 68.66666667])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model=RandomForestRegressor()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
prediction=model.predict(x_test)

# %%
prediction
# Out:
# array([51.82666667, 89.9       , 71.06333333, 58.26      , 70.49666667,
#        67.80333333, 46.72      , 48.74333333, 68.06      , 58.64333333,
#        85.69333333, 78.96333333, 68.16666667, 68.74666667, 63.78666667,
#        84.31333333, 73.84333333, 50.62333333, 86.37333333, 69.11666667,
#        63.6       , 66.99666667, 61.14      , 46.64      , 61.85666667])

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(prediction,y_test))
# Out:
# 0.9855032300175525
